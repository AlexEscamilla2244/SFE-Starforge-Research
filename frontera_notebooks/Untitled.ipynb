# %%
import h5py
import numpy as np
import astropy.units as u

# %%
with h5py.File("/scratch3/03532/mgrudic/STARFORGE_RT/STARFORGE_v1.2/M2e4_R10_Z1_S0_A2_B0.1_I1_Res271_n2_sol0.5_42/output/dustemission/snapshot_2650.dustemission.hdf5", "r") as F:
    Surface_Den = F["SurfaceDensity_Msun_pc2"][:]
    
surface_unit = 1 * (u.solMass / u.pc**2)
new_den = (Surface_Den.flatten() * (u.solMass / u.pc**2))
A_i= ((20 / 1024)**2 )* u.pc**2
Mask = new_den > 1000 *  surface_unit
A = (np.sum(Mask) *  A_i).value

# %%
A
# Out:
# 0.4375457763671875

# %%
M_Gas = np.sum(A_i * new_den[Mask]).value

# %%
M_Gas
# Out:
# 684.9266274616258

# %%
(Surface_Den > 1000).sum()
# Out:
# 1147
